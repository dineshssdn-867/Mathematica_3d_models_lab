# %%
S=Plot[Sin[x],{x,-Pi,Pi}]
# Out:
# -Graphics-

# %%
Plot3D[Cos[x y], {x, -Pi, Pi}, {y, -Pi, Pi},
AxesLabel-> {"x1", "x2", "f(x1,x2)"},
PlotLabel-> "f=cos(x1,x2)",
ColorFunction->"Rainbow",
PlotStyle->Opacity[0.25],
FaceGrids->All]
# Out:
# -Graphics3D-

# %%
Plot3D[Sin[x y],{x,-Pi,Pi},{y,-Pi,Pi}]
# Out:
# -Graphics3D-

# %%
Plot3D[Cos[x1]*x2, {x1, -Pi, Pi}, {x2, -10,16},
ViewPoint->{0,-∞,0}
]
# Out:
# -Graphics3D-

# %%
Plot3D[{x^2-0.333y^2}, {x,-3,3}, {y,-6,6}, ColorFunction->"Rainbow"]
# Out:
# -Graphics3D-

# %%
ContourPlot3D[x^2 + y^2 - z^2 == 1, {x, -3 , 3 }, {y, -3 , 3}, {z, -3, 3}, ColorFunction->"Rainbow"]
# Out:
# -Graphics3D-

# %%
ContourPlot3D[Tan[x]+Tan[y]+Tan[z]==0, {x, -Pi , 5Pi}, {y, -Pi, 5Pi}, {z, -Pi, 5Pi}, Extrusion->0.2, Mesh->False, PlotPoints->10]
# Out:
# -Graphics3D-

# %%
ContourPlot3D[Cos[x]+Cos[y]+Cos[z]==0, {x, -Pi , 5Pi}, {y, -Pi, 5Pi}, {z, -Pi, 5Pi}, Extrusion->0.2, Mesh->False, PlotPoints->10]
# Out:
# -Graphics3D-

# %%
ParametricPlot3D[{{x,y,√(x^2+y^2-9)},{x,y,-√(x^2+y^2-9)}}, {x,-16,16}, {y,-16,16}, Mesh-> None, PlotStyle->Thickness[2.0]]
# Out:
# -Graphics3D-

# %%
ContourPlot3D[Cot[x]+Cot[y]+Cot[z]==0, {x, -Pi , 5Pi}, {y, -Pi, 5Pi}, {z, -Pi, 5Pi}, Extrusion->0.2, Mesh->False, PlotPoints->10]
# Out:
# -Graphics3D-

# %%
(* L system *)
str = First@
   SubstitutionSystem[{"A" -> "AB+BA+B", "B" -> "B+AAB"}, "A", {7}];

asc = <|"A" -> {1, 0}, "B" -> {0, Pi/2}, "+" -> {0, -Pi/2}|>;
Graphics[
 Line@AnglePath@Lookup[asc, Characters[str]]
]
# Out:
# -Graphics-
